# %%
from roboflow import Roboflow

rf = Roboflow(api_key="v3DSBGCMIBcRmpookRFy")
project = rf.workspace("prueba-hvgyw").project("armas_blancas-rayosx-6aakf")
version = project.version(1)

dataset = version.download(
    "yolov8",
    location="Armas_Blancas_RayosX-1")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Armas_Blancas_RayosX-1 in yolov8:: 100%|██████████| 17710/17710 [00:09<00:00, 1920.46it/s]

# %%
from pathlib import Path
import torch
from ultralytics import YOLO

DATASET_YAML = r"Armas_Blancas_RayosX-1\data.yaml"

device = 0 if torch.cuda.is_available() else "cpu"
print("Dispositivo:", "GPU" if device == 0 else "CPU")

model = YOLO("yolov8s.pt")
results = model.train(
    data=DATASET_YAML,
    epochs=10,
    imgsz=640,
    batch=16,
    device=device,
    name="smoke_test",
    exist_ok=True,
    verbose=True
)

print("Entrenamiento de prueba terminado.")
# Out:
# Dispositivo: GPU
# New https://pypi.org/project/ultralytics/8.3.233 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223  Python-3.10.18 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# ...
