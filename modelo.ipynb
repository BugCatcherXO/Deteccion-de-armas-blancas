# %%
from pathlib import Path
import torch
from ultralytics import YOLO

DATASET_YAML = r"yolo_data\dataset.yaml"

# elegimos dispositivo
device = 0 if torch.cuda.is_available() else "cpu"
print("Dispositivo:", "GPU" if device == 0 else "CPU")

# cargamos pesos base y lanzamos entrenamiento corto
model = YOLO("yolov8s.pt")
results = model.train(
    data=DATASET_YAML,
    epochs=10,
    imgsz=640,
    batch=16,
    device=device,
    name="smoke_test",
    exist_ok=True,
    verbose=True
)

print("Entrenamiento de prueba terminado.")
print("Revisa la carpeta runs para ver logs, gráficos y el mejor checkpoint.")
# Out:
# Dispositivo: GPU
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223  Python-3.10.18 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo_data\dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=smoke_test, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\wail-\Desktop\armas_blancas\runs\detect\smoke_test, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# Model summary: 129 layers, 11,136,374 parameters, 11,136,358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      11 # cargamos pesos base y lanzamos entrenamiento corto
#      12 model = YOLO("yolov8s.pt")
# ---> 13 results = model.train(
#      14     data=DATASET_YAML,
#      15     epochs=10,
#      16     imgsz=640,
#      17     batch=16,
#      18     device=device,
#      19     name="smoke_test",
#      20     exist_ok=True,
#      21     verbose=True
#      22 )
#      24 print("Entrenamiento de prueba terminado.")
#      25 print("Revisa la carpeta runs para ver logs, gráficos y el mejor checkpoint.")
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\trainer.py:240, in BaseTrainer.train(self)
#     237         ddp_cleanup(self, str(file))
#     239 else:
# --> 240     self._do_train()
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\trainer.py:361, in BaseTrainer._do_train(self)
#     359 if self.world_size > 1:
#     360     self._setup_ddp()
# --> 361 self._setup_train()
#     363 nb = len(self.train_loader)  # number of batches
#     364 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\trainer.py:298, in BaseTrainer._setup_train(self)
#     296 if self.amp and RANK in {-1, 0}:  # Single-GPU and DDP
#     297     callbacks_backup = callbacks.default_callbacks.copy()  # backup callbacks as check_amp() resets them
# --> 298     self.amp = torch.tensor(check_amp(self.model), device=self.device)
#     299     callbacks.default_callbacks = callbacks_backup  # restore callbacks
#     300 if RANK > -1 and self.world_size > 1:  # DDP
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\utils\checks.py:809, in check_amp(model)
#     806 try:
#     807     from ultralytics import YOLO
# --> 809     assert amp_allclose(YOLO("yolo11n.pt"), im)
#     810     LOGGER.info(f"{prefix}checks passed ✅")
#     811 except ConnectionError:
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\utils\checks.py:799, in check_amp.<locals>.amp_allclose(m, im)
#     797 a = m(batch, imgsz=imgsz, device=device, verbose=False)[0].boxes.data  # FP32 inference
#     798 with autocast(enabled=True):
# --> 799     b = m(batch, imgsz=imgsz, device=device, verbose=False)[0].boxes.data  # AMP inference
#     800 del m
#     801 return a.shape == b.shape and torch.allclose(a, b.float(), atol=0.5)
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\model.py:187, in Model.__call__(self, source, stream, **kwargs)
#     158 def __call__(
#     159     self,
#     160     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     161     stream: bool = False,
#     162     **kwargs: Any,
#     163 ) -> list:
#     164     """
#     165     Alias for the predict method, enabling the model instance to be callable for predictions.
#     166
#    (...)
#     185         ...     print(f"Detected {len(r)} objects in image")
#     186     """
# --> 187     return self.predict(source, stream, **kwargs)
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\model.py:557, in Model.predict(self, source, stream, predictor, **kwargs)
#     555 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556     self.predictor.set_prompts(prompts)
# --> 557 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\predictor.py:230, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     228     return self.stream_inference(source, model, *args, **kwargs)
#     229 else:
# --> 230     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\torch\utils\_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\predictor.py:307, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     303     self.setup_model(model)
#     305 with self._lock:  # for thread-safe inference
#     306     # Setup source every time predict is called
# --> 307     self.setup_source(source if source is not None else self.args.source)
#     309     # Check if save_dir/ label file exists
#     310     if self.args.save or self.args.save_txt:
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\engine\predictor.py:262, in BasePredictor.setup_source(self, source)
#     254 """
#     255 Set up source and inference mode.
#     256
#    (...)
#     259         Source for inference.
#     260 """
#     261 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
# --> 262 self.dataset = load_inference_source(
#     263     source=source,
#     264     batch=self.args.batch,
#     265     vid_stride=self.args.vid_stride,
#     266     buffer=self.args.stream_buffer,
#     267     channels=getattr(self.model, "ch", 3),
#     268 )
#     269 self.source_type = self.dataset.source_type
#     270 long_sequence = (
#     271     self.source_type.stream
#     272     or self.source_type.screenshot
#     273     or len(self.dataset) > 1000  # many images
#     274     or any(getattr(self.dataset, "video_flag", [False]))
#     275 )
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\data\build.py:422, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     420     dataset = LoadScreenshots(source, channels=channels)
#     421 elif from_img:
# --> 422     dataset = LoadPilAndNumpy(source, channels=channels)
#     423 else:
#     424     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\data\loaders.py:532, in LoadPilAndNumpy.__init__(self, im0, channels)
#     530 self.paths = [getattr(im, "filename", "") or f"image{i}.jpg" for i, im in enumerate(im0)]
#     531 pil_flag = "L" if channels == 1 else "RGB"  # grayscale or RGB
# --> 532 self.im0 = [self._single_check(im, pil_flag) for im in im0]
#     533 self.mode = "image"
#     534 self.bs = len(self.im0)
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\data\loaders.py:532, in <listcomp>(.0)
#     530 self.paths = [getattr(im, "filename", "") or f"image{i}.jpg" for i, im in enumerate(im0)]
#     531 pil_flag = "L" if channels == 1 else "RGB"  # grayscale or RGB
# --> 532 self.im0 = [self._single_check(im, pil_flag) for im in im0]
#     533 self.mode = "image"
#     534 self.bs = len(self.im0)
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\ultralytics\data\loaders.py:541, in LoadPilAndNumpy._single_check(im, flag)
#     539 assert isinstance(im, (Image.Image, np.ndarray)), f"Expected PIL/np.ndarray image type, but got {type(im)}"
#     540 if isinstance(im, Image.Image):
# --> 541     im = np.asarray(im.convert(flag))
#     542     # adding new axis if it's grayscale, and converting to BGR if it's RGB
#     543     im = im[..., None] if flag == "L" else im[..., ::-1]
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\PIL\Image.py:993, in Image.convert(self, mode, matrix, dither, palette, colors)
#     990 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     991     deprecate(mode, 12)
# --> 993 self.load()
#     995 has_transparency = "transparency" in self.info
#     996 if not mode and self.mode == "P":
#     997     # determine default mode
#
# File c:\Users\wail-\.conda\envs\ml\lib\site-packages\PIL\ImageFile.py:300, in ImageFile.load(self)
#     297         raise OSError(msg)
#     299 b = b + s
# --> 300 n, err_code = decoder.decode(b)
#     301 if n < 0:
#     302     break
#
# KeyboardInterrupt:
